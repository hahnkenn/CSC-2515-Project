# %% [markdown]
# ## Use Kaggle API to download dataset

# %%
from google.colab import files

# !pip install -q kaggle

# %%
# Upload kaggle API key file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8db4e9cf-7320-4a67-b8e5-5c9c25846cd5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8db4e9cf-7320-4a67-b8e5-5c9c25846cd5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !ls ~/.kaggle
# !chmod 600 /root/.kaggle/kaggle.json
# Out:
# kaggle.json

# %%
# !kaggle competitions download -c jigsaw-toxic-comment-classification-challenge
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.9 / client 1.5.4)
# Downloading test_labels.csv.zip to /content
#   0% 0.00/1.46M [00:00<?, ?B/s]
# 100% 1.46M/1.46M [00:00<00:00, 49.1MB/s]
# Downloading sample_submission.csv.zip to /content
#   0% 0.00/1.39M [00:00<?, ?B/s]
# 100% 1.39M/1.39M [00:00<00:00, 94.5MB/s]
# Downloading test.csv.zip to /content
#  73% 17.0M/23.4M [00:01<00:01, 4.99MB/s]
# 100% 23.4M/23.4M [00:01<00:00, 14.7MB/s]
# Downloading train.csv.zip to /content
#  34% 9.00M/26.3M [00:01<00:02, 6.21MB/s]
# 100% 26.3M/26.3M [00:01<00:00, 20.2MB/s]

# %%
# !unzip -q train.csv.zip -d .
# !unzip -q test.csv.zip -d .
# !ls
# Out:
# kaggle.json  sample_submission.csv.zip	test.csv.zip	     train.csv
# sample_data  test.csv			test_labels.csv.zip  train.csv.zip

# %% [markdown]
# ## Preview data

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#                  id  ... identity_hate
# 0  0000997932d777bf  ...             0
# 1  000103f0d9cfb60f  ...             0
# 2  000113f07ec002fd  ...             0
# 3  0001b41b1c6bb37e  ...             0
# 4  0001d958c54c6e35  ...             0
#
# [5 rows x 8 columns]

# %%
df.shape
# Out:
# (159571, 8)

# %%
df['toxic'].value_counts()
# Out:
# 0    144277
# 1     15294
# Name: toxic, dtype: int64

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/.git/
